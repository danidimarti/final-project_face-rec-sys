# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd

# %% [markdown]
# #### Spotify Token
# 1. Get Auth for App
# - Client_ID
# - Client_Secret
#
#
# 2. Get Auth for queries
# - token

# %%
def save_token():
    load_dotenv('../.env')
    CLIENT_ID = os.environ.get('CLIENT_ID')
    CLIENT_SECRET = os.environ.get('CLIENT_SECRET')
    command = f"""echo "CLIENT_ID='{CLIENT_ID}'\nCLIENT_SECRET='{CLIENT_SECRET}'" > .env"""
    os.system(command)

# %%
def spotify_token ():
    
    """This function refreshes a 'queries token' for a given app on Spotify.
    queries token are refreshed every 3600 seconds
    returns: token as a string
    """

    # 1. Defining: credentials fot the app
    
    CLIENT_ID = os.getenv("CLIENT_ID")
    CLIENT_SECRET = os.getenv("CLIENT_SECRET")
    
    #2. Request
    
    body_params = {"grant_type":"client_credentials"}
    url = "https://accounts.spotify.com/api/token"
    response = requests.post(url, data=body_params, auth=(CLIENT_ID,CLIENT_SECRET))
    
    try:
        token = response.json()["access_token"]
        return token

    except:
        print("The request did not go through. Maybe check credentials?")

# %%
token = spotify_token()
token
# Out:
# 'BQDrGf764cnVqpHWG-adk3v5au15aMMbvfwAB22lCBjUhNaePAiIUPBQEBX_IRp7876AplYYwhFsl8ktGwqZvXB4TvrqfD00f5s-sW8lKzxmGVqG9DZH'

# %%
#token
headers = {"Authorization":f"Bearer {token}", 
            
}

# %% [markdown]
# #### Get Mood Playlists
#
# 1. url_base: core api url.
#
# 2. select mood playlists for sentiments/moods:
#     > happy (smile) </br>
#     > sad (sad face) </br>
#     > flerty (wink) </br>
#     > neutral (normal face) </br>
#     > angry (frown, lip-up)
#
# 3. [get playlists items from api](https://developer.spotify.com/console/get-playlist-tracks/)
#     > artist name,
#     > song name,
#     > song links,
#     > popularity,
#
# 4. create mood column for each dictionary
#
# 5. merge all playlists into single dataset

# %%
url_base = 'https://api.spotify.com/v1/playlists/'

# %%
query = f'https://api.spotify.com/v1/playlists/{playlist_id}/tracks'

# %%
angry = '78Gzl2X1zog4nGbm1qIdM9' #https://open.spotify.com/playlist/78Gzl2X1zog4nGbm1qIdM9
happy = '37i9dQZF1DXdPec7aLTmlC' #https://open.spotify.com/playlist/37i9dQZF1DXdPec7aLTmlC?si=edc1e3f30bdb400b&nd=1
happy_2 = '37i9dQZF1DX2sUQwD7tbmL' #https://open.spotify.com/playlist/37i9dQZF1DX2sUQwD7tbmL?si=9a88891af3d94949&nd=1
sad = '37i9dQZF1DX3YSRoSdA634' #https://open.spotify.com/playlist/37i9dQZF1DX3YSRoSdA634?si=b63116e34e2b477f&nd=1
flerty = '37i9dQZF1DXdl6IPOySdX4' #https://open.spotify.com/playlist/37i9dQZF1DXdl6IPOySdX4?si=2c03e0f3491d469c&nd=1

# %%
def get_playlist (playlist_id):
    token = spotify_token()
    headers = {"Authorization":f"Bearer {token}"}

    
    
    query = f'https://api.spotify.com/v1/playlists/{playlist_id}/tracks'
        
    try:    
        return requests.get(query, headers=headers).json()
    except:
        token = spotify_token()
        return requests.get(query, headers=headers).json()

# %%
get_playlist('78Gzl2X1zog4nGbm1qIdM9')
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/78Gzl2X1zog4nGbm1qIdM9/tracks?offset=0&limit=100',
#  'items': [{'added_at': '2022-01-28T02:53:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22addb47ii2lsy2mafmln2pdi'},
#     'href': 'https://api.spotify.com/v1/users/22addb47ii2lsy2mafmln2pdi',
#     'id': '22addb47ii2lsy2mafmln2pdi',
#     'type': 'user',
#     'uri': 'spotify:user:22addb47ii2lsy2mafmln2pdi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v2WhpA59TJSdPh7LCx1lN'},
#        'href': 'https://api.spotify.com/v1/artists/5v2WhpA59TJSdPh7LCx1lN',
#        'id': '5v2WhpA59TJSdPh7LCx1lN',
#        'name': 'BONES',
#        'type': 'artist',
#        'uri': 'spotify:artist:5v2WhpA59TJSdPh7LCx1lN'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1vurSXXQeO0h4sy1BBDYrt'},
#      'href': 'https://api.spotify.com/v1/albums/1vurSXXQeO0h4sy1BBDYrt',
#      'id': '1vurSXXQeO0h4sy1BBDYrt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d653f88352c2da499146473f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d653f88352c2da499146473f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d653f88352c2da499146473f',
#        'width': 64}],
#      'name': 'IFeelLikeDirt',
#      'release_date': '2019-11-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1vurSXXQeO0h4sy1BBDYrt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v2WhpA59TJSdPh7LCx1lN'},
#       'href': 'https://api.spotify.com/v1/artists/5v2WhpA59TJSdPh7LCx1lN',
#       'id': '5v2WhpA59TJSdPh7LCx1lN',
#       'name': 'BONES',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v2WhpA59TJSdPh7LCx1lN'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 75428,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1285882'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5XKZua8kqgHwcxeKiMIjge'},
#     'href': 'https://api.spotify.com/v1/tracks/5XKZua8kqgHwcxeKiMIjge',
#     'id': '5XKZua8kqgHwcxeKiMIjge',
#     'is_local': False,
#     'name': 'AirplaneMode',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/12b494202632f2aaa06ae538f62ec89f4969cac9?cid=5237554f6e9545d5bfa9b4d6499acc37',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5XKZua8kqgHwcxeKiMIjge'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-28T02:53:08Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22addb47ii2lsy2mafmln2pdi'},
#     'href': 'https://api.spotify.com/v1/users/22addb47ii2lsy2mafmln2pdi',
#     'id': '22addb47ii2lsy2mafmln2pdi',
#     'type': 'user',
#     'uri': 'spotify:user:22addb47ii2lsy2mafmln2pdi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1VPmR4DJC1PlOtd0IADAO0'},
#        'href': 'https://api.spotify.com/v1/artists/1VPmR4DJC1PlOtd0IADAO0',
#        'id': '1VPmR4DJC1PlOtd0IADAO0',
#        'name': '$uicideboy$',
#        'type': 'artist',
#        'uri': 'spotify:artist:1VPmR4DJC1PlOtd0IADAO0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3dgsCZMswt6TWbsKcMgoO2'},
#      'href': 'https://api.spotify.com/v1/albums/3dgsCZMswt6TWbsKcMgoO2',
#      'id': '3dgsCZMswt6TWbsKcMgoO2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b25093d7ccdce4a848988f9e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b25093d7ccdce4a848988f9e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b25093d7ccdce4a848988f9e',
#        'width': 64}],
#      'name': 'Long Term Effects of SUFFERING',
#      'release_date': '2021-08-13',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3dgsCZMswt6TWbsKcMgoO2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1VPmR4DJC1PlOtd0IADAO0'},
#       'href': 'https://api.spotify.com/v1/artists/1VPmR4DJC1PlOtd0IADAO0',
#       'id': '1VPmR4DJC1PlOtd0IADAO0',
#       'name': '$uicideboy$',
#       'type': 'artist',
#       'uri': 'spotify:artist:1VPmR4DJC1PlOtd0IADAO0'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 178131,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZAPK2000200'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Q9nA56DKKJhj4cHMbHlAS'},
#     'href': 'https://api.spotify.com/v1/tracks/2Q9nA56DKKJhj4cHMbHlAS',
#     'id': '2Q9nA56DKKJhj4cHMbHlAS',
#     'is_local': False,
#     'name': 'Ugliest',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bdf02a3f3e2c1ded89f66ed33fa549f0981a10a0?cid=5237554f6e9545d5bfa9b4d6499acc37',
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:2Q9nA56DKKJhj4cHMbHlAS'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-28T02:53:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22addb47ii2lsy2mafmln2pdi'},
#     'href': 'https://api.spotify.com/v1/users/22addb47ii2lsy2mafmln2pdi',
#     'id': '22addb47ii2lsy2mafmln2pdi',
#     'type': 'user',
#     'uri': 'spotify:user:22addb47ii2lsy2mafmln2pdi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OYIkXBBN6ET96coWyWAXh'},
#        'href': 'https://api.spotify.com/v1/artists/4OYIkXBBN6ET96coWyWAXh',
#        'id': '4OYIkXBBN6ET96coWyWAXh',
#        'name': 'Germ',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OYIkXBBN6ET96coWyWAXh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5eWTQHm7yXnuxlHpG9Lf23'},
#      'href': 'https://api.spotify.com/v1/albums/5eWTQHm7yXnuxlHpG9Lf23',
#      'id': '5eWTQHm7yXnuxlHpG9Lf23',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273244a762c5d43209cb768b0b1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02244a762c5d43209cb768b0b1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851244a762c5d43209cb768b0b1',
#        'width': 64}],
#      'name': 'GERM HAS A DEATHWISH',
#      'release_date': '2019-03-08',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:5eWTQHm7yXnuxlHpG9Lf23'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OYIkXBBN6ET96coWyWAXh'},
#       'href': 'https://api.spotify.com/v1/artists/4OYIkXBBN6ET96coWyWAXh',
#       'id': '4OYIkXBBN6ET96coWyWAXh',
#       'name': 'Germ',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OYIkXBBN6ET96coWyWAXh'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1VPmR4DJC1PlOtd0IADAO0'},
#       'href': 'https://api.spotify.com/v1/artists/1VPmR4DJC1PlOtd0IADAO0',
#       'id': '1VPmR4DJC1PlOtd0IADAO0',
#       'name': '$uicideboy$',
#       'type': 'artist',
#       'uri': 'spotify:artist:1VPmR4DJC1PlOtd0IADAO0'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 109898,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZAPK1800034'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3aEDTqPcVXDiuKXaedAZgx'},
#     'href': 'https://api.spotify.com/v1/tracks/3aEDTqPcVXDiuKXaedAZgx',
#     'id': '3aEDTqPcVXDiuKXaedAZgx',
#     'is_local': False,
#     'name': 'AWKWARD CAR DRIVE',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/29642ff776e230891c4136583d57b297ee88ca4f?cid=5237554f6e9545d5bfa9b4d6499acc37',
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:3aEDTqPcVXDiuKXaedAZgx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-28T02:53:22Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22addb47ii2lsy2mafmln2pdi'},
#     'href': 'https://api.spotify.com/v1/users/22addb47ii2lsy2mafmln2pdi',
#     'id': '22addb47ii2lsy2mafmln2pdi',
#     'type': 'user',
#     'uri': 'spotify:user:22addb47ii2lsy2mafmln2pdi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v2WhpA59TJSdPh7LCx1lN'},
#        'href': 'https://api.spotify.com/v1/artists/5v2WhpA59TJSdPh7LCx1lN',
#        'id': '5v2WhpA59TJSdPh7LCx1lN',
#        'name': 'BONES',
#        'type': 'artist',
#        'uri': 'spotify:artist:5v2WhpA59TJSdPh7LCx1lN'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0Wh0QKnKq6j7Tlkj7RYE9u'},
#      'href': 'https://api.spotify.com/v1/albums/0Wh0QKnKq6j7Tlkj7RYE9u',
#      'id': '0Wh0QKnKq6j7Tlkj7RYE9u',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273728911900d9b0213ae28c81c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02728911900d9b0213ae28c81c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851728911900d9b0213ae28c81c',
#        'width': 64}],
#      'name': 'Skinny',
#      'release_date': '2014-09-02',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:0Wh0QKnKq6j7Tlkj7RYE9u'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v2WhpA59TJSdPh7LCx1lN'},
#       'href': 'https://api.spotify.com/v1/artists/5v2WhpA59TJSdPh7LCx1lN',
#       'id': '5v2WhpA59TJSdPh7LCx1lN',
#       'name': 'BONES',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v2WhpA59TJSdPh7LCx1lN'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 175307,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'CA5KR1567856'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7nH4UnffKuEHlbjCnSRYRG'},
#     'href': 'https://api.spotify.com/v1/tracks/7nH4UnffKuEHlbjCnSRYRG',
#     'id': '7nH4UnffKuEHlbjCnSRYRG',
#     'is_local': False,
#     'name': 'WhereTheTreesMeetTheFreeway',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/20ddfa1995c26baeb5073f01b0807ecd3a056799?cid=5237554f6e9545d5bfa9b4d6499acc37',
#     'track': True,
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:7nH4UnffKuEHlbjCnSRYRG'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-28T02:53:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22addb47ii2lsy2mafmln2pdi'},
#     'href': 'https://api.spotify.com/v1/users/22addb47ii2lsy2mafmln2pdi',
#     'id': '22addb47ii2lsy2mafmln2pdi',
#     'type': 'user',
#     'uri': 'spotify:user:22addb47ii2lsy2mafmln2pdi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5No9X0ZejwFDnD1dVllwQA'},
#        'href': 'https://api.spotify.com/v1/artists/5No9X0ZejwFDnD1dVllwQA',
#        'id': '5No9X0ZejwFDnD1dVllwQA',
#        'name': 'Terror Reid',
#        'type': 'artist',
#        'uri': 'spotify:artist:5No9X0ZejwFDnD1dVllwQA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CG',
#       'CH',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4c3IqJDtpEvmXPUQ1uN8DU'},
#      'href': 'https://api.spotify.com/v1/albums/4c3IqJDtpEvmXPUQ1uN8DU',
#      'id': '4c3IqJDtpEvmXPUQ1uN8DU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e7eeab9869edcbc49c6108c9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e7eeab9869edcbc49c6108c9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e7eeab9869edcbc49c6108c9',
#        'width': 64}],
#      'name': 'Uppercuts',
#      'release_date': '2017-04-07',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4c3IqJDtpEvmXPUQ1uN8DU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5No9X0ZejwFDnD1dVllwQA'},
#       'href': 'https://api.spotify.com/v1/artists/5No9X0ZejwFDnD1dVllwQA',
#       'id': '5No9X0ZejwFDnD1dVllwQA',
#       'name': 'Terror Reid',
#       'type': 'artist',
#       'uri': 'spotify:artist:5No9X0ZejwFDnD1dVllwQA'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'DJ',
#      'ZM',
#      'CG',
#      'TJ',
#      'VE',
#      'ET'],
#     'disc_number': 1,
#     'duration_ms': 180000,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'TCACZ1778879'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7EpACeh5ooHUb0AnQ3f3Xl'},
#     'href': 'https://api.spotify.com/v1/tracks/7EpACeh5ooHUb0AnQ3f3Xl',
#     'id': '7EpACeh5ooHUb0AnQ3f3Xl',
#     'is_local': False,
#     'name': 'Uppercuts',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2a6fbe476421dfdcee5051bcd326a06ff354bac6?cid=5237554f6e9545d5bfa9b4d6499acc37',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7EpACeh5ooHUb0AnQ3f3Xl'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-28T02:53:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22addb47ii2lsy2mafmln2pdi'},
#     'href': 'https://api.spotify.com/v1/users/22addb47ii2lsy2mafmln2pdi',
#     'id': '22addb47ii2lsy2mafmln2pdi',
#     'type': 'user',
#     'uri': 'spotify:user:22addb47ii2lsy2mafmln2pdi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1VPmR4DJC1PlOtd0IADAO0'},
#        'href': 'https://api.spotify.com/v1/artists/1VPmR4DJC1PlOtd0IADAO0',
#        'id': '1VPmR4DJC1PlOtd0IADAO0',
#        'name': '$uicideboy$',
#        'type': 'artist',
#        'uri': 'spotify:artist:1VPmR4DJC1PlOtd0IADAO0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3dgsCZMswt6TWbsKcMgoO2'},
#      'href': 'https://api.spotify.com/v1/albums/3dgsCZMswt6TWbsKcMgoO2',
#      'id': '3dgsCZMswt6TWbsKcMgoO2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b25093d7ccdce4a848988f9e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b25093d7ccdce4a848988f9e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b25093d7ccdce4a848988f9e',
#        'width': 64}],
#      'name': 'Long Term Effects of SUFFERING',
#      'release_date': '2021-08-13',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3dgsCZMswt6TWbsKcMgoO2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1VPmR4DJC1PlOtd0IADAO0'},
#       'href': 'https://api.spotify.com/v1/artists/1VPmR4DJC1PlOtd0IADAO0',
#       'id': '1VPmR4DJC1PlOtd0IADAO0',
#       'name': '$uicideboy$',
#       'type': 'artist',
#       'uri': 'spotify:artist:1VPmR4DJC1PlOtd0IADAO0'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 160240,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZAPK2000197'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5C33XaYYMuEKvGmABGHwOa'},
#     'href': 'https://api.spotify.com/v1/tracks/5C33XaYYMuEKvGmABGHwOa',
#     'id': '5C33XaYYMuEKvGmABGHwOa',
#     'is_local': False,
#     'name': 'Bleach',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/06cc4c91a714b11b2c0b216b16899e42a449520b?cid=5237554f6e9545d5bfa9b4d6499acc37',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:5C33XaYYMuEKvGmABGHwOa'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-28T02:53:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22addb47ii2lsy2mafmln2pdi'},
#     'href': 'https://api.spotify.com/v1/users/22addb47ii2lsy2mafmln2pdi',
#     'id': '22addb47ii2lsy2mafmln2pdi',
#     'type': 'user',
#     'uri': 'spotify:user:22addb47ii2lsy2mafmln2pdi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5No9X0ZejwFDnD1dVllwQA'},
#        'href': 'https://api.spotify.com/v1/artists/5No9X0ZejwFDnD1dVllwQA',
#        'id': '5No9X0ZejwFDnD1dVllwQA',
#        'name': 'Terror Reid',
#        'type': 'artist',
#        'uri': 'spotify:artist:5No9X0ZejwFDnD1dVllwQA'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0nnFac30YlVu2aB0aFwxPI'},
#      'href': 'https://api.spotify.com/v1/albums/0nnFac30YlVu2aB0aFwxPI',
#      'id': '0nnFac30YlVu2aB0aFwxPI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bfff5fb0d686e3b7287fdd0c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bfff5fb0d686e3b7287fdd0c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bfff5fb0d686e3b7287fdd0c',
#        'width': 64}],
#      'name': 'HOT VODKA 1',
#      'release_date': '2020-05-08',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:0nnFac30YlVu2aB0aFwxPI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5No9X0ZejwFDnD1dVllwQA'},
#       'href': 'https://api.spotify.com/v1/artists/5No9X0ZejwFDnD1dVllwQA',
#       'id': '5No9X0ZejwFDnD1dVllwQA',
#       'name': 'Terror Reid',
#       'type': 'artist',
#       'uri': 'spotify:artist:5No9X0ZejwFDnD1dVllwQA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nXOZlYoAD67hF9aUEncMY'},
#       'href': 'https://api.spotify.com/v1/artists/4nXOZlYoAD67hF9aUEncMY',
#       'id': '4nXOZlYoAD67hF9aUEncMY',
#       'name': 'Pouya',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nXOZlYoAD67hF9aUEncMY'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 224000,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBKPL2094538'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0wMBON83H9bcRTTWhprziY'},
#     'href': 'https://api.spotify.com/v1/tracks/0wMBON83H9bcRTTWhprziY',
#     'id': '0wMBON83H9bcRTTWhprziY',
#     'is_local': False,
#     'name': 'Outlawz',
#     'popularity': 6,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0wMBON83H9bcRTTWhprziY'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-28T02:53:33Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22addb47ii2lsy2mafmln2pdi'},
#     'href': 'https://api.spotify.com/v1/users/22addb47ii2lsy2mafmln2pdi',
#     'id': '22addb47ii2lsy2mafmln2pdi',
#     'type': 'user',
#     'uri': 'spotify:user:22addb47ii2lsy2mafmln2pdi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CG',
#       'CH',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5qRYOrYeEri6gV2PRFfn3H'},
#      'href': 'https://api.spotify.com/v1/albums/5qRYOrYeEri6gV2PRFfn3H',
#      'id': '5qRYOrYeEri6gV2PRFfn3H',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730905700f494c025d93b27a96',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020905700f494c025d93b27a96',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510905700f494c025d93b27a96',
#        'width': 64}],
#      'name': 'Death by Dishonor',
#      'release_date': '2017-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5qRYOrYeEri6gV2PRFfn3H'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3uL4UpqShC4p2x1dJutoRW'},
#       'href': 'https://api.spotify.com/v1/artists/3uL4UpqShC4p2x1dJutoRW',
#       'id': '3uL4UpqShC4p2x1dJutoRW',
#       'name': 'Ghostemane',
#       'type': 'artist',
#       'uri': 'spotify:artist:3uL4UpqShC4p2x1dJutoRW'},
# ...
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CG',
#       'CH',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1pE34bOBLSJHEnrth42CKd'},
#      'href': 'https://api.spotify.com/v1/albums/1pE34bOBLSJHEnrth42CKd',
#      'id': '1pE34bOBLSJHEnrth42CKd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273da692533de4109c09f5d525c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02da692533de4109c09f5d525c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851da692533de4109c09f5d525c',
#        'width': 64}],
#      'name': 'Fuck Everybody',
#      'release_date': '2017-06-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1pE34bOBLSJHEnrth42CKd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5No9X0ZejwFDnD1dVllwQA'},
#       'href': 'https://api.spotify.com/v1/artists/5No9X0ZejwFDnD1dVllwQA',
#       'id': '5No9X0ZejwFDnD1dVllwQA',
#       'name': 'Terror Reid',
#       'type': 'artist',
#       'uri': 'spotify:artist:5No9X0ZejwFDnD1dVllwQA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3QryVD03gGZOLQQXjy3EoA'},
#       'href': 'https://api.spotify.com/v1/artists/3QryVD03gGZOLQQXjy3EoA',
#       'id': '3QryVD03gGZOLQQXjy3EoA',
#       'name': 'Getter',
#       'type': 'artist',
#       'uri': 'spotify:artist:3QryVD03gGZOLQQXjy3EoA'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'DJ',
#      'ZM',
#      'CG',
#      'TJ',
#      'VE',
#      'ET'],
#     'disc_number': 1,
#     'duration_ms': 169780,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'TCADD1722731'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7fMYjEMZYwNs2hO16BZstm'},
#     'href': 'https://api.spotify.com/v1/tracks/7fMYjEMZYwNs2hO16BZstm',
#     'id': '7fMYjEMZYwNs2hO16BZstm',
#     'is_local': False,
#     'name': 'Fuck Everybody',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cbffdb30bab19bae37dea298f49d77f40cf8b3bb?cid=5237554f6e9545d5bfa9b4d6499acc37',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7fMYjEMZYwNs2hO16BZstm'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-11-11T05:59:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22addb47ii2lsy2mafmln2pdi'},
#     'href': 'https://api.spotify.com/v1/users/22addb47ii2lsy2mafmln2pdi',
#     'id': '22addb47ii2lsy2mafmln2pdi',
#     'type': 'user',
#     'uri': 'spotify:user:22addb47ii2lsy2mafmln2pdi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3v0QTRruILayLe5VsaYdvk'},
#        'href': 'https://api.spotify.com/v1/artists/3v0QTRruILayLe5VsaYdvk',
#        'id': '3v0QTRruILayLe5VsaYdvk',
#        'name': 'HAARPER',
#        'type': 'artist',
#        'uri': 'spotify:artist:3v0QTRruILayLe5VsaYdvk'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4uVFNuPonAm2Y6NxvvLuNs'},
#      'href': 'https://api.spotify.com/v1/albums/4uVFNuPonAm2Y6NxvvLuNs',
#      'id': '4uVFNuPonAm2Y6NxvvLuNs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c56ccbe96a76ebeb69b0e2e5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c56ccbe96a76ebeb69b0e2e5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c56ccbe96a76ebeb69b0e2e5',
#        'width': 64}],
#      'name': 'Wtf U Mean',
#      'release_date': '2020-02-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4uVFNuPonAm2Y6NxvvLuNs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3v0QTRruILayLe5VsaYdvk'},
#       'href': 'https://api.spotify.com/v1/artists/3v0QTRruILayLe5VsaYdvk',
#       'id': '3v0QTRruILayLe5VsaYdvk',
#       'name': 'HAARPER',
#       'type': 'artist',
#       'uri': 'spotify:artist:3v0QTRruILayLe5VsaYdvk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0dlDsD7y6ccmDm8tuWCU6F'},
#       'href': 'https://api.spotify.com/v1/artists/0dlDsD7y6ccmDm8tuWCU6F',
#       'id': '0dlDsD7y6ccmDm8tuWCU6F',
#       'name': 'Freddie Dredd',
#       'type': 'artist',
#       'uri': 'spotify:artist:0dlDsD7y6ccmDm8tuWCU6F'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 118034,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZFZ52052994'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3PHt7AdVhjIMS5Yw5RIZKU'},
#     'href': 'https://api.spotify.com/v1/tracks/3PHt7AdVhjIMS5Yw5RIZKU',
#     'id': '3PHt7AdVhjIMS5Yw5RIZKU',
#     'is_local': False,
#     'name': 'Wtf U Mean',
#     'popularity': 63,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3PHt7AdVhjIMS5Yw5RIZKU'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-11-11T06:00:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22addb47ii2lsy2mafmln2pdi'},
#     'href': 'https://api.spotify.com/v1/users/22addb47ii2lsy2mafmln2pdi',
#     'id': '22addb47ii2lsy2mafmln2pdi',
#     'type': 'user',
#     'uri': 'spotify:user:22addb47ii2lsy2mafmln2pdi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1VPmR4DJC1PlOtd0IADAO0'},
#        'href': 'https://api.spotify.com/v1/artists/1VPmR4DJC1PlOtd0IADAO0',
#        'id': '1VPmR4DJC1PlOtd0IADAO0',
#        'name': '$uicideboy$',
#        'type': 'artist',
#        'uri': 'spotify:artist:1VPmR4DJC1PlOtd0IADAO0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2VrpzWjnsiELWKXOJAFhme'},
#      'href': 'https://api.spotify.com/v1/albums/2VrpzWjnsiELWKXOJAFhme',
#      'id': '2VrpzWjnsiELWKXOJAFhme',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dcff3103179d992594a227db',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dcff3103179d992594a227db',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dcff3103179d992594a227db',
#        'width': 64}],
#      'name': "My Liver Will Handle What My Heart Can't",
#      'release_date': '2015-09-21',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2VrpzWjnsiELWKXOJAFhme'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1VPmR4DJC1PlOtd0IADAO0'},
#       'href': 'https://api.spotify.com/v1/artists/1VPmR4DJC1PlOtd0IADAO0',
#       'id': '1VPmR4DJC1PlOtd0IADAO0',
#       'name': '$uicideboy$',
#       'type': 'artist',
#       'uri': 'spotify:artist:1VPmR4DJC1PlOtd0IADAO0'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 127523,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM8DG1600549'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4JnpbIUaZWRLsv0iK2svlz'},
#     'href': 'https://api.spotify.com/v1/tracks/4JnpbIUaZWRLsv0iK2svlz',
#     'id': '4JnpbIUaZWRLsv0iK2svlz',
#     'is_local': False,
#     'name': 'T.R.U. (Totally Rotten Underground)',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9fee56b429458bb33ef94e0dd7558cf2a7b05a48?cid=5237554f6e9545d5bfa9b4d6499acc37',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:4JnpbIUaZWRLsv0iK2svlz'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/78Gzl2X1zog4nGbm1qIdM9/tracks?offset=100&limit=100',
#  'offset': 0,
#  'previous': None,
#  'total': 134}

# %%
 'track': {'album': {'album_type': 'album',
     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v2WhpA59TJSdPh7LCx1lN'},
       'href': 'https://api.spotify.com/v1/artists/5v2WhpA59TJSdPh7LCx1lN',
       'id': '5v2WhpA59TJSdPh7LCx1lN',
       'name': 'BONES',
       'type': 'artist',
# Out:
#   Cell In[31], line 2
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v2WhpA59TJSdPh7LCx1lN'},
#                 ^
# SyntaxError: '{' was never closed

# %%
artist_name = response['albums'][5]['artists'][0]['name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 artist_name = response['albums'][5]['artists'][0]['name']
#
# NameError: name 'response' is not defined

# %%
def get_playlist(playlist_id):
    token = spotify_token()
    headers = {"Authorization":f"Bearer {token}"}
    query = f'https://api.spotify.com/v1/playlists/{playlist_id}/tracks'
        
    try:    
        return requests.get(query, headers=headers).json()
    except:
        token = spotify_token()
        return requests.get(query, headers=headers).json()

# Dictionary that maps playlist ids to labels
playlist_labels = {
    '78Gzl2X1zog4nGbm1qIdM9': 'angry',
    '37i9dQZF1DXdPec7aLTmlC': 'happy',
    '37i9dQZF1DX2sUQwD7tbmL': 'happy',
    '37i9dQZF1DX3YSRoSdA634': 'sad',
    '37i9dQZF1DXdl6IPOySdX4': 'flerty'

 }

# Loop through the playlist ids and extract tracks information
tracks_info = []
for playlist_id, label in playlist_labels.items():
    response = get_playlist(playlist_id)
    tracks = response['items']
    while response['next']:
        response = requests.get(response['next'], headers=headers).json()
        tracks.extend(response['items'])
    for track in tracks:
        track_info = {
            'playlist_id': playlist_id,
            'label': label,
            'track_name': track['track']['name'],
            'artist_name': track['track']['artists'][0]['name'],
            'album_name': track['track']['album']['name'],
            'track_link': track['track']['external_urls']['spotify'],
            'track_id': track['track']['id']           

        }
        tracks_info.append(track_info)

# Store the tracks information in a dataframe
df_tracks_info = pd.DataFrame(tracks_info)

# %%
df_tracks_info
# Out:
#                 playlist_id   label                               track_name  \
# 0    78Gzl2X1zog4nGbm1qIdM9   angry                             AirplaneMode
# 1    78Gzl2X1zog4nGbm1qIdM9   angry                                  Ugliest
# 2    78Gzl2X1zog4nGbm1qIdM9   angry                        AWKWARD CAR DRIVE
# 3    78Gzl2X1zog4nGbm1qIdM9   angry              WhereTheTreesMeetTheFreeway
# 4    78Gzl2X1zog4nGbm1qIdM9   angry                                Uppercuts
# ..                      ...     ...                                      ...
# 649  37i9dQZF1DXdl6IPOySdX4  flerty                                   Frozen
# 650  37i9dQZF1DXdl6IPOySdX4  flerty  sex money feelings die - slowed version
# 651  37i9dQZF1DXdl6IPOySdX4  flerty                                      WFM
# 652  37i9dQZF1DXdl6IPOySdX4  flerty            Come and See Me (feat. Drake)
# 653  37i9dQZF1DXdl6IPOySdX4  flerty                             Wicked Games
#
#        artist_name                               album_name  \
# 0            BONES                            IFeelLikeDirt
# 1      $uicideboy$           Long Term Effects of SUFFERING
# 2             Germ                     GERM HAS A DEATHWISH
# 3            BONES                                   Skinny
# 4      Terror Reid                                Uppercuts
# ..             ...                                      ...
# 649        Madonna                                   Frozen
# 650       Lykke Li  sex money feelings die (slowed version)
# 651       RealestK                         Dreams 2 Reality
# 652  PARTYNEXTDOOR                     PARTYNEXTDOOR 3 (P3)
# 653     Kiana Ledé                                 Selfless
#
#                                             track_link                track_id
# 0    https://open.spotify.com/track/5XKZua8kqgHwcxe...  5XKZua8kqgHwcxeKiMIjge
# 1    https://open.spotify.com/track/2Q9nA56DKKJhj4c...  2Q9nA56DKKJhj4cHMbHlAS
# 2    https://open.spotify.com/track/3aEDTqPcVXDiuKX...  3aEDTqPcVXDiuKXaedAZgx
# 3    https://open.spotify.com/track/7nH4UnffKuEHlbj...  7nH4UnffKuEHlbjCnSRYRG
# 4    https://open.spotify.com/track/7EpACeh5ooHUb0A...  7EpACeh5ooHUb0AnQ3f3Xl
# ..                                                 ...                     ...
# 649  https://open.spotify.com/track/6lknMmJZALXxx7e...  6lknMmJZALXxx7emwwZWLX
# 650  https://open.spotify.com/track/0dkvbYmXYEPK7gG...  0dkvbYmXYEPK7gGMdytmfI
# 651  https://open.spotify.com/track/6z6OFc8qYsqUBSO...  6z6OFc8qYsqUBSOWta3nLV
# 652  https://open.spotify.com/track/6cEguiQecbXrFls...  6cEguiQecbXrFlsnMi2ysr
# 653  https://open.spotify.com/track/0TYhf0MgEj4YJaK...  0TYhf0MgEj4YJaKwo5c4Km
#
# [654 rows x 7 columns]

# %%
df_tracks_info.to_csv('data/spotify_tracks.csv')
